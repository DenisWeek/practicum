# %% [markdown]
# <div class="alert alert-info"><big><b>Комментарий ревьюера<!----></b></big><br>Привет! 👋<br><br> Ничего не поменялось, меня всё ещё зовут Дмитрий Кирсанов. <br><br>Комментарии всё ещё обозначены пометкой <b>Комментарий ревьюера<!----></b> и всё ещё содержат описание <br><span class="alert-success">✔️ хорошего, 👍 отличного, 📝 советов</span>,&nbsp;&nbsp;<span class="alert-warning">📌 важного, ⚠️ замечаний, 💡 рекомендаций</span>,&nbsp;&nbsp;<span class="alert-danger">🔧 доработок, 🚫 ошибок, 🔴 блокеров или 👀 вопросов.</span><br><br>После того, как замечание будет устранено, я сменю красный цвет на жёлтый, чтобы тебе было удобнее выделять те места, которые требуют доработки. Код, которым я предлагаю выделять твои комментарии<!--
# НЕ НАДО КОПИРОВАТЬ КОД, ПРИ ПОМОЩИ КОТОРОГО Я ВЫВОЖУ КОД-->:<br><code>&lt;div class=&quot;alert btn-primary&quot;&gt;&lt;b&gt;Комментарий студента:&lt;/b&gt;&lt;br&gt;   Ок   &lt;/div&gt;</code><br><!--
# КОПИРОВАТЬ НАДО, КОГДА ВИДЕН ОФОРМЛЕННЫЙ ТЕКСТ-->Всё ещё просьба задавать вопросы и описывать изменения в проект.</div>

# %% [markdown]
# ## Проект для Яндекс.Практикума

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 4</b>&nbsp;🔧<br>
# У нас четвёртая итерация из шести доступных, всё уже практически доделано, остались мелкие шероховатости.
#
# * исправить некоторые выводы и формулировки
# * посчитать и описать корреляции по всем
# * указать отточные интервалы по доходу и балансу в читаемой менеджерами записи
# * использовать все выделенные признаки отточности хоть раз при построении сегментов, строить отточные сегменты, а не наоборот
#
# Уже пора присылать презентацию!
# </div>

# %% [markdown]
# ## Материалы:

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2</b>&nbsp;✔️<br>
# Титульный лист презентации должен быть оформлен так, чтобы на неё было удобно сослаться. В самой презентации не нужно мельчить и нужно снабжать графики тезисами. У вас должны быть упомянуты все характеристики и в визуально наглядном виде представлены не только результаты работы (сформированные сегменты и рекомендации), но и ход ваших мыслей, почему именно эти характеристики вы взяли и именно так, а другие не взяли. Обязательно указываем типичного отточного, подчёркиваем чем он отличается от типичного неотточного, что сравнивали стат.гипотезами; результаты корреляционного анализа читаемо; уровни оттока по категориальным характеристикам; как поняли что непрерывные нужно разделить именно так, как разделили.
# </div>

# %% [markdown]
# * [Презентация] (https://disk.yandex.ru/client/disk)

# %% [markdown]
# * [Дашборд] (https://public.tableau.com/app/profile/.50766184/viz/BankScrooge_16936658883820/Sheet2?publish=yes)

# %% [markdown]
# ## Введение
# Существует проблема оттока клиентов банка «Метанпром». Данный банк располагается в Ярославле и областных городах: Ростов Великий и Рыбинск. Клиент считается ушедшим, если он попросил закрыть договор о дальнейшем сотрудничестве
#
# ### Цель исследования:
#
# Провести анализ и подготовить план действий по удержанию клиентов
#
# ### Ход исследования:
#
# Данное исследование будет разбито на несколько больших частей:
#
#
# - Обработка и подготовка исходных данных к анализу; - Сформировать типичные портреты клиентов; - Проанализировать основные признаки, наиболее сильно влияющие на отток; - Сформулировать и проверить статистические гипотезы, влияющие на отток клиентов; - Сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами: - выделить целевые группы клиентов - предложить меры по снижению оттока - определить другие особенности взаимодействия с клиентами
# Перед началом основной части исследования неободимо проверить все необходимые данные на ошибки и оценить их влияние на дальнейшее исследование, а на этапе предобработки найти возможность исправить самые критичные ошибки данных

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Проекту нужно название и введение, люди, открыв его в портфолио, должны сразу считать, что в работе делалось и зачем, вникнуть в контекст проблемы.
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# ## Подготовка данных к исследованию

# %% [markdown]
# ### Загрузка данных

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('https://code.s3.yandex.net/datasets/bank_scrooge.csv')
data.head()
# Out:
#    USERID  score       city gender   age  equity     balance  products  \
# 0  183012  850.0    Рыбинск      Ж  25.0       1    59214.82         2
# 1  146556  861.0    Рыбинск      Ж  37.0       5   850594.33         3
# 2  120722  892.0    Рыбинск      Ж  30.0       0         NaN         1
# 3  225363  866.0  Ярославль      Ж  51.0       5  1524746.26         2
# 4  157978  730.0  Ярославль      М  34.0       5      174.00         1
#
#    credit_card  last_activity  EST_SALARY  churn
# 0            0              1    75719.14      1
# 1            1              0    86621.77      0
# 2            1              1   107683.34      0
# 3            0              1   174423.53      1
# 4            1              0    67353.16      1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   USERID         10000 non-null  int64
#  1   score          10000 non-null  float64
#  2   city           10000 non-null  object
#  3   gender         10000 non-null  object
#  4   age            9974 non-null   float64
#  5   equity         10000 non-null  int64
#  6   balance        7705 non-null   float64
#  7   products       10000 non-null  int64
#  8   credit_card    10000 non-null  int64
#  9   last_activity  10000 non-null  int64
#  10  EST_SALARY     10000 non-null  float64
#  11  churn          10000 non-null  int64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 937.6+ KB

# %%
data = data.rename(columns = {'USERID': 'user_id', 'EST_SALARY': 'est_salary'})

# %%
data.columns
# Out:
# Index(['user_id', 'score', 'city', 'gender', 'age', 'equity', 'balance',
#        'products', 'credit_card', 'last_activity', 'est_salary', 'churn'],
#       dtype='object')

# %% [markdown]
# ### Изучение пропусков

# %% [markdown]
# Имеются пропуски данных в столбцах *age* и *balance*, изучим строки с пропусками
#
# Начнем со строк с пропусками в колонке *age*

# %%
missing_age_rows = data[data['age'].isnull()]
missing_age_rows

missing_percentages = (data.isnull().sum() / len(data)) * 100

plt.figure(figsize=(10, 6))
sns.barplot(x=missing_percentages.index, y=missing_percentages.values)
plt.title('Процент пропусков по категориям')
plt.xlabel('Категория')
plt.ylabel('Процент пропусков')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>Аналитики данных способны работать с большими данными, не просматривая весь их массив вручную.
#
# Также, не стоит отделять для исследования только строки с пропусками. Рассматривая только строки с пропусками мы, например, видим, что пропусков много в одном из городов. Но никак интерпретировать это не можем, так как это, возможно, просто самый большой город, в котором у нас больше всего клиентов.
#
# Также распределение значений в тех строках, в которых встречаются пропуски, сами по себе, за исключением каких-то крайних случаев, не покажут нам, аномальное это распределение, отличается оно от распределения строк без пропусков или нет.
#
# Информативно было бы посмотреть процент пропусков по разным категориям.
# </div>

# %%
# missing_age_rows = data[data['balance'].isnull()]
# missing_age_rows.head(20)

# Рассчитываем процент пропущенных значений для каждой колонки
missing_percentages = (data.isnull().sum() / len(data)) * 100

# Строим график процента пропущенных значений для каждой категории
plt.figure(figsize=(10, 6))
sns.barplot(x=missing_percentages.index, y=missing_percentages.values)
plt.title('Процент пропусков по категориям')
plt.xlabel('Категория')
plt.ylabel('Процент пропусков')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Проходим по колонкам с пропущенными значениями и анализируем их распределение
for column in data.columns:
    if data[column].isnull().any():
        print(f"Переменная: {column}")
        print("С пропущенными значениями:")
        print(data[column][data[column].isnull()].value_counts(normalize=True))
        print("Без пропущенных значений:")
        print(data[column][~data[column].isnull()].value_counts(normalize=True))
        print("="*50)

# Создаем новый бинарный признак для обозначения пропущенного возраста
data['age_missing'] = data['age'].isnull().astype(int)

# Создаем новый бинарный признак для обозначения пропущенного баланса
data['balance_missing'] = data['balance'].isnull().astype(int)

# Рассчитываем матрицу корреляций
corr_matrix = data.corr()

# Строим тепловую карту корреляций
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Тепловая карта корреляций')
plt.show()

features_to_compare = ['score', 'equity', 'products', 'credit_card', 'est_salary']  # Выберите признаки для анализа

for feature in features_to_compare:
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    sns.histplot(data[~data['age'].isnull()][feature], bins=20, kde=True, label='С пропусками в возрасте')
    sns.histplot(data[data['age'].isnull()][feature], bins=20, kde=True, label='Без пропусков в возрасте')
    plt.title(f'Распределение {feature} с разделением по возрасту')
    plt.legend()

    plt.subplot(1, 2, 2)
    sns.histplot(data[~data['balance'].isnull()][feature], bins=20, kde=True, label='С пропусками в балансе')
    sns.histplot(data[data['balance'].isnull()][feature], bins=20, kde=True, label='Без пропусков в балансе')
    plt.title(f'Распределение {feature} с разделением по балансу')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# Переменная: age
# С пропущенными значениями:
# Series([], Name: age, dtype: float64)
# Без пропущенных значений:
# 36.0    0.041508
# 37.0    0.040305
# 33.0    0.039302
# 35.0    0.038901
# 34.0    0.038500
#           ...
# 83.0    0.000301
# 82.0    0.000201
# 84.0    0.000201
# 79.0    0.000201
# 86.0    0.000201
# Name: age, Length: 68, dtype: float64
# ...
# Переменная: balance
# С пропущенными значениями:
# Series([], Name: balance, dtype: float64)
# Без пропущенных значений:
# 26.00         0.00026
# 0.00          0.00026
# 38.00         0.00026
# 39.00         0.00026
# 59214.82      0.00013
#                ...
# 924011.29     0.00013
# 1452458.87    0.00013
# 1294391.76    0.00013
# 1106127.02    0.00013
# 1180886.70    0.00013
# Name: balance, Length: 7701, dtype: float64
# ...

# %% [markdown]
# Пропущенные значения имуют только переменные age и balance
#
# На тепловой карте корреляций видно, что новые бинарные признаки 'age_missing' и 'balance_missing' слабо коррелируют с другими признаками, что может говорить о том, что они не имеют сильной взаимосвязи с остальными переменными.

# %% [markdown]
# score - 0.14
#
# equity - -0.71
#
# products - -0.49
#
# credit_card - 0.16
#
# est_salary - 0.31
#
# churn - -0.25
#
# Оценим эти корреляции по шкале Чеддока:
#
# 0.00 - 0.19: Очень слабая корреляция
#
# 0.20 - 0.39: Слабая корреляция
#
# 0.40 - 0.59: Умеренная корреляция
#
# 0.60 - 0.79: Значительная корреляция
#
# 0.80 - 1.00: Очень высокая корреляция
#
# Теперь проанализируем значения корреляции по отношению к столбцу "balance_missing":
#
# score: Слабая положительная корреляция.
#
# equity: Значительная отрицательная корреляция.
#
# products: Значительная отрицательная корреляция.
#
# credit_card: Слабая положительная корреляция.
#
# est_salary: Умеренная положительная корреляция.
#
# churn: Умеренная отрицательная корреляция.
#
# Исходя из анализа, можно сделать следующие выводы:
#
# Значительная отрицательная корреляция с "equity" и "products" может указывать на то, что клиенты с более высоким "equity" и меньшим числом "products" чаще имеют пропущенные значения в столбце "balance_missing".
#
# Умеренная положительная корреляция с "est_salary" может означать, что клиенты с более высоким доходом более склонны иметь пропущенные значения в "balance_missing".
#
# Умеренная отрицательная корреляция с "churn" может указывать на то, что клиенты, которые не покидают компанию, имеют меньше пропущенных значений в "balance_missing".
#
# Остальные корреляции имеют очень слабые или слабые значения и, вероятно, не оказывают значительного влияния на столбец "balance_missing".
#
# "score" и наличие кредитной карты не оказывают существенного влияния на наличие пропущенных значений в столбце "balance_missing"

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 3</b>&nbsp;🔴<br>
# Перечисли, пожалуйста, все корреляции данных в столбцах датасета с balance_missing, которые по модулю превосходят .1 (10%), опиши их по шкале Чеддока. Сделай снова выводы.
# </div>

# %% [markdown]
# Гистограммы распределения переменных 'balance' и 'age' с и без пропущенных значений показывают, что пропущенные значения скорее всего не являются случайными

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 3</b>&nbsp;🔴<br>
# На гистограммах выше распределение строк с пропусками должно быть показано оранжевым, однако на графике ничего нет, плюс график по балансу нечитаем из-за масштаба по оси X.
#
# Используй plt.xlim
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 4</b>&nbsp;⚠️<br>
# При рассмотрении строк с пропусками и без надо строить графики не по тем столбцам, в которых пропуски, а по всем остальным. По балансу ты просто отображаешь тобой же импутированный ноль. У нас нет никаких значений баланса в строках с пропусками, нам не на что ориентироваться, но мы можем посмотреть, например, как распределён баланс у тех, у кого есть пропуски в возрасте в сравнении с остальными и как (что ты сделал) распределён возраст у тех, у кого пропуски в балансе в сравнении с остальными.
#
# Т.е. тут имело смысл смотреть скор и доходы.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>Если за минусом шума в рамках каждой из характеристик распределение строк с пропусками повторяет распределение строк без пропусков, то можно сказать, что пропуски имеют тип MCAR (Missing Completely At Random). Такие пропуски мы можем заменить средним или медианой.
#
# Если пропусков почти нет среди какой-то группы, но в остальном они распределены случайно, то это уже MAR (Missing At Random), это значит, что пропуски хотя связаны с какой-то наблюдаемой характеристикой (или несколькими), но в остальном случайно распределены. Можно заменять <a href='https://tproger.ru/translations/data-imputation/'>моделью</a> или средними по группам.
#
# Пропуски типа MNAR (Missing Not At Random) наблюдаются тогда, когда пропуски связаны с какой-то не наблюдаемой характеристикой, которой нету в наших данных. Тут без гипотезы о том, чем пропуски вызваны ничего не сделаешь.
#
# <span class="alert-danger">Пожалуйста, выяви наличие или отсутствие зависимости пропусков от данных, исследовав данные в разрезе наличия или отсутствия пропусков</span> (одним из методов —  средние, корреляции  с новой фиктивной переменной, связанной с пропусками, графики в разрезе наличия пропусков или доля пропусков по категориям, также можно сделать пару вызовов value_counts(normalize=True) и сравнить проценты распределения).
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Выше ты считаешь корреляции с пропущенным возрастом, но с пропущенным балансом их не смотришь, и, самое главное, не делаешь выводов из графиков.
#
# Также выше проводятся не имеющие смысла стат.тесты. Посмотри что именно ты подаёшь в стат. тест и попробуй сформулировать нулевую и альтернативную гипотезы.
# </div><div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;💡<br>
# Тут этого не нужно делать, но у value_counts есть опция <tt>dropna=False</tt>
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 4</b>&nbsp;📝<br>
# Выше по корреляциям мы видим, что пропуски в балансе не являются случайными, по пропускам в возрасте это сложнее сказать - их меньше и зависимости менее ярко выражены - можно принять и такое и другое решение и поступить с ними любым способом кроме замены нулём. Лучше всего заменить по группам пола и городов, например.
# </div>

# %% [markdown]
# ### Выдвигаем и проверяем гипотезы по пропускам

# %% [markdown]
# Видим, что в строках, где имеются пропуски данных, целевая переменная равна 0, тогда сразу сформулируем первую гипотезу - если нет данных о возрасте, балансе, то целевая переменная *churn* будет равна нулю
#
# Для проверки этой гипотезы сначала построим круговые диаграммы распределения нашего таргета для данных, где имеются пропуски
#
# Начнем с признака *age*

# %%
missing_age_rows = data[data['age'].isnull()]

churn_counts = missing_age_rows['churn'].value_counts(dropna=False)
plt.figure(figsize=(6, 6))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Распределение таргет-переменной churn')
plt.show()

# %% [markdown]
# Видим, что 96,2% людей, у которых нет информации о возрасте целевая переменная равна 0 - следовательно он уходит
#
# Проверим нашу гипотезу с p_value в стандартном значении 0.05, проверять будем с помощью t-теста
#
# Гипотеза: у людей, у которых нет информации о возрасте, чаще уходят

# %%
churn_with_missing_age = data[data['age'].isnull()]['churn']
churn_without_missing_age = data[data['age'].notnull()]['churn']

stat, p_value = ttest_ind(churn_with_missing_age, churn_without_missing_age)

print(f"T-статистика: {stat}")
print(f"P-value: {p_value}")
# Out:
# T-статистика: -1.8995155415942675
# P-value: 0.0575254757520439

# %% [markdown]
# Получаем p_value равное 0.057525475752043906, что говорит о том, что у нас нет статистической разницы, значит пропуски в столбце *age* не сильно влияют на нашу таргет переменную *churn*

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# Проверим признак *balance*

# %%
missing_age_rows = data[data['balance'].isnull()]

churn_counts = missing_age_rows['churn'].value_counts(dropna=False)
plt.figure(figsize=(6, 6))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Распределение таргет-переменной churn')
plt.show()

# %% [markdown]
# Видим, что лишь 0.6% людей уходят, формируем гипотезу: люди, у которых нет информации в столбце-признаке *balance* чаще остаются.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>
# <s>Скорее верна обратная ситуация.</s> 1 в признаке пропуска это клиент уходит, 0 - остаётся.
# </div>

# %% [markdown]
# Проверим это с помощью t-теста на уровне значимости 0.05

# %%
churn_with_missing_balance = data[data['balance'].isnull()]['churn']
churn_without_missing_balance = data[data['balance'].notnull()]['churn']

stat, p_value = ttest_ind(churn_with_missing_balance, churn_without_missing_balance)

print(f"T-статистика: {stat}")
print(f"P-value: {p_value}")
# Out:
# T-статистика: -25.753507417587404
# P-value: 1.144732515032309e-141

# %% [markdown]
# Получаем очень низкое значение p_value и подтверждает, что данное различие статистически значимо, получаем первый сегмент людей, которые чаще остаются - люди, неимеющие информацию в столбце *balance*

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🚫<br>
# Остались неверные выводы.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 4</b>&nbsp;🔴<br>
# Люди, у которых пропущено значение в балансе точно уходят чаще? Проверь другим методом, если уверен в этом, пожалуйста.
# </div>

# %% [markdown]
# Пропуски заполнить мы не можем, потому что не имеем никаких дополнительных сведений, алгоритмов, с помощью которых можно было бы заполнить пропуски

# %%
mean_product = data['products'].mean()
std_product = data['products'].std()
upper_threshold = mean_product + 3 * std_product
data = data[data['products'] <= upper_threshold]
data = data[data['products'] > 0]

# %%
### КОД РЕВЬЮЕРА
data.products.min()
# Out:
# 1

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Не убрали аномалию из продуктов
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Всё ещё не убрали. У нас не может быть клиентов, у которых нет никаких продуктов. Если у клиента нет продуктов, значит он услугами банка не пользуется. И, пожалуйста, не надо под пометкой "КОД РЕВЬЮЕРА" писать свой код. Было вот так:
#
# ! [image.png](attachment:image.png)
#
# Как я получил проект:
#
# ! [image-2.png](attachment:image-2.png)
# </div>

# %%
data.columns = data.columns.str.lower()

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2</b>&nbsp;👍<br>
# Хорошее использование <a href='https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html'>строкового ацессора</a> pandas
#
# Стоит также не забывать, что у него есть другие полезные методы, кроме .lower
# </div>

# %%
# Проверить наличие дубликатов
duplicates = data.duplicated()

# Вывести количество полных дубликатов
print("Количество дубликатов:", duplicates.sum())

duplicates_partial = data.duplicated(subset=['user_id', 'city'], keep=False)
print("Количество неполных дубликатов:", duplicates_partial.sum())

subset_columns = ['user_id', 'gender', 'age', 'equity', 'balance', 'products', 'credit_card', 'last_activity', 'est_salary', 'churn']
duplicates_partial = data.duplicated(subset=subset_columns, keep=False)
print("Количество неполных дубликатов:", duplicates_partial.sum())

duplicates_user_id = data['user_id'].duplicated(keep=False)
print("Количество дубликатов по user_id:", duplicates_user_id.sum())

data.drop_duplicates(subset=['user_id'], keep=False, inplace=True)

duplicates_user_id = data['user_id'].duplicated(keep=False)
print("Количество дубликатов по user_id:", duplicates_user_id.sum())
# Out:
# Количество дубликатов: 0
# Количество неполных дубликатов: 0
# Количество неполных дубликатов: 0
# Количество дубликатов по user_id: 144
# Количество дубликатов по user_id: 0

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔧<br>
# А у нас были полные дубликаты? Если да, то сколько? <span class="alert-danger">Возможно остались неявные дубликаты?</span>
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 3</b>&nbsp;🔴<br>
# Полных дубликатов не было, ок.
#
# А неполные были? Почему мы искали раньше их по user_id и городам, а теперь не ищем?
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 4</b>&nbsp;⚠️<br>
# Код выше никак не помогает выявить неполные дубликаты, т.к. ты включаешь все колонки в поиск. Тут можно было найти, что в столбце user_id должны быть все значения уникальны, этого не наблюдается.
# </div>

# %%
### КОД РЕВЬЮЕРА

import itertools as it

subset_general = data.columns[data.nunique().gt(2)].difference(['balance_filled', 'age_filled'])
dupl = []
for combination in it.combinations(subset_general,r=3):
    dupl.append({'combination':combination,'duplicates':data.duplicated(subset=combination, keep=False).sum()})
    
df_pupl = pd.DataFrame(dupl).sort_values('duplicates',ascending=False)
df_pupl[df_pupl.combination.apply(lambda tupl: "user_id" in tupl)].head(10)
# Out:
#                         combination  duplicates
# 42      (city, est_salary, user_id)           0
# 44        (city, products, user_id)           0
# 45           (city, score, user_id)           0
# 48    (equity, est_salary, user_id)           0
# 5           (age, balance, user_id)           0
# 50      (equity, products, user_id)           0
# 51         (equity, score, user_id)           0
# 53  (est_salary, products, user_id)           0
# 54     (est_salary, score, user_id)           0
# 39          (city, equity, user_id)           0

# %%
data['gender_encoded'] = pd.factorize(data['gender'])[0]

# Применение One-Hot Encoding для переменной city
city_encoded = pd.get_dummies(data['city'], prefix='city', drop_first=True)

# Объединение закодированного столбца с исходными данными
data = pd.concat([data, city_encoded], axis=1)

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Города закодированы некорректно. См. комментарий из декомпозиции.
#
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔧<br>Необходимо будет закодировать текстовые столбцы численно, тут это пол и города. Кодировку городов как 0-1-2 или 1-2-3 делать в этом проекте нельзя. Нужно три столбца (описано ниже).
# </div>
#
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;📝<br>
# Категориальные данные <a href='https://discover6sigma.org/post/2011/06/desc-stats/'>делятся на</a> упорядоченные (уровень образования, удовлетворённости пользователя) и неупорядоченные (город, брачный статус и т.п.). Центральные тенденции второго можно смотреть при помощи моды. Будет некорректно задавать неупорядоченным категориям какой-то числовой порядок и смотреть средние арифметические. К средним каких-то ординальных показателей, или численных показателей, содержащих большое число значений, например возраста, надо относиться так, что это центр распределения, которое может иметь какую-то сложную природу. Бинарные показатели, если к ним применить среднее, показывают нам долю тех клиентов, у которых этот бинарный показатель равен единице.
#
# Уже на этапе подготовки данных важно закодировать данные численно. Для того, чтобы применять среднее и смотреть корреляции какого-то числового показателя с категориальным неупорядоченным, можно применить <a href='https://habr.com/ru/post/666234/'>one-hot кодирование</a>, проще всего это сделать при помощи <tt>pandas.get_dummies</tt>. Чтобы при этом не потерять оригинальный столбец, стоит сделать его копию и использовать параметр <tt>columns</tt> (чтобы перекодированию подвергся или подверглись только те столбцы, которые нам нужно перекодировать).</div>
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %%
### КОД РЕВЬЮЕРА
data.columns
# Out:
# Index(['user_id', 'score', 'city', 'gender', 'age', 'equity', 'balance',
#        'products', 'credit_card', 'last_activity', 'est_salary', 'churn',
#        'age_missing', 'balance_missing', 'gender_encoded', 'city_Рыбинск',
#        'city_Ярославль'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# <s>Не привели наименование столбцов к единому виду.</s>
#
# Не проверили на дубликаты.
#
# Не закодировали численно <s>пол и</s> города.
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# ### Графики численных переменных

# %% [markdown]
# Для начала изобразим круговую диаграмму распределения бинарного таргета *churn*

# %%
churn_counts = data['churn'].value_counts(dropna=False)
plt.figure(figsize=(6, 6))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Распределение таргет-переменной churn')
plt.show()

# %% [markdown]
# Видим, что всего 81,8% - уходят, 18,2% - остаются

# %% [markdown]
# <div class="alert alert-warning"><s><b>Комментарий ревьюера</b>&nbsp;🚫</div>

# %% [markdown]
# Теперь построим распределения boxplot для числовых переменных, посмотрим есть ли выбросы, также изобразим также гистограммы этих переменных

# %%
numeric_features = ['score', 'age', 'equity', 'balance', 'products', 'est_salary']

# %%
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")

for feature in numeric_features:
    plt.figure()
    sns.boxplot(data=data, y=feature)
    plt.title(f"Boxplot of {feature}")
    plt.show()
    
    plt.figure()
    sns.histplot(data=data, x=feature, bins=20, kde=True)
    plt.title(f"Histogram of {feature}")
    plt.show()

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера</b>&nbsp;👍<br>
# Хорошая автоматизация
# </div>

# %% [markdown]
# Видим, что выбросы есть у всех числовых переменных, но все они являются нормальными кроме столбца *balance*, изучим медиану-среднее у всех числовых столбцов

# %%
churn_grouped = data.groupby('churn')[numeric_features].agg(['mean', 'median'])

churn_grouped
# Out:
#             score               age           equity              balance  \
#              mean median       mean median      mean median          mean
# churn
# 0      845.345801  848.0  43.029980   40.0  2.382462    3.0  7.336754e+05
# 1      862.837117  866.0  41.527541   39.0  3.753689    4.0  1.127258e+06
#
#                    products            est_salary
#            median      mean median           mean      median
# churn
# 0      475609.850  1.753778    2.0  147712.050452  118224.635
# 1      775349.215  2.360386    2.0  147318.918462  124966.110

# %% [markdown]
# Видим, что в столбце *balance* среднее много больше баланса

# %%
for feature in numeric_features:
    mean_exited = churn_grouped.loc[1, (feature, 'mean')]
    mean_not_exited = churn_grouped.loc[0, (feature, 'mean')]
    mean_percent_diff = ((mean_exited - mean_not_exited) / mean_not_exited) * 100

    median_exited = churn_grouped.loc[1, (feature, 'median')]
    median_not_exited = churn_grouped.loc[0, (feature, 'median')]
    median_percent_diff = ((median_exited - median_not_exited) / median_not_exited) * 100

    print(f"Feature: {feature}")
    print(f"Mean Percent Difference: {mean_percent_diff:.2f}%")
    print(f"Median Percent Difference: {median_percent_diff:.2f}%")
    print("=" * 50)
# Out:
# Feature: score
# Mean Percent Difference: 2.07%
# Median Percent Difference: 2.12%
# ...
# Feature: age
# Mean Percent Difference: -3.49%
# Median Percent Difference: -2.50%
# ...
# Feature: equity
# Mean Percent Difference: 57.56%
# Median Percent Difference: 33.33%
# ...
# Feature: balance
# Mean Percent Difference: 53.65%
# Median Percent Difference: 63.02%
# ...
# Feature: products
# Mean Percent Difference: 34.59%
# Median Percent Difference: 0.00%
# ...
# Feature: est_salary
# Mean Percent Difference: -0.27%
# Median Percent Difference: 5.70%
# ...

# %% [markdown]
# Score: Средний и медианный балл имеют небольшое положительное различие (около 2%), что может указывать на небольшую зависимость между баллом и оттоком.
#
# Age: Средний и медианный возраст в группе неоттока незначительно выше среднего и медианного возраста в группе оттока, что может указывать на некоторое влияние возраста на отток.
#
# Equity: Среднее и медианное значение equity в группе оттока выше почти в 60% и 33%, соответственно, чем в группе неоттока. Это может говорить о том, что клиенты с более высоким equity склонны к оттоку.
#
# Balance: Средний и медианный баланс в группе оттока значительно выше (более 50%) по сравнению с группой неоттока. Это может указывать на более активное использование счета в группе оттока.
#
# Products: Средний балл и медиана в группе неоттока значительно выше, что может свидетельствовать о том, что клиенты, пользующиеся большим количеством продуктов, менее склонны к оттоку.
#
# Est_Salary: Разница в средних и медианных доходах между группами оттока и неоттока минимальна (менее 6%). Этот показатель, вероятно, имеет незначительное влияние на отток.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# Тут как-то неверно сформулировано, и мы уже начали анализ не знакончив подготовку данных.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;📌<br>
# Пожалуйста, транспонируй таблицу выше и по каждой характеристике посчитай на сколько процентов характеристика отточного клиента выше(ниже) характеристики неотточного. </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b> Сделано неоптимальным образом, см. ниже как удобнее (я делаю не самым простым способом, чтобы не менять сами переменные), смотри прежде всего на результат.</div>

# %%
### КОД РЕВЬЮЕРА 2
churn_grouped.T.assign(diff = churn_grouped.apply(lambda row: row[1]/row[0] - 1))\
    .sort_values('diff',key=abs,ascending=False).query('diff > .1')\
    .style.format("{:_.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_9d1c4">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >churn</th>
#       <th id="T_9d1c4_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_9d1c4_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_9d1c4_level0_col2" class="col_heading level0 col2" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d1c4_level0_row0" class="row_heading level0 row0" >balance</th>
#       <th id="T_9d1c4_level1_row0" class="row_heading level1 row0" >median</th>
#       <td id="T_9d1c4_row0_col0" class="data row0 col0" >475_609.85</td>
#       <td id="T_9d1c4_row0_col1" class="data row0 col1" >775_349.21</td>
#       <td id="T_9d1c4_row0_col2" class="data row0 col2" >0.63</td>
#     </tr>
#     <tr>
#       <th id="T_9d1c4_level0_row1" class="row_heading level0 row1" >equity</th>
# ...

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>Почему бинарные характеристики мы не включаем в numeric_features?
#
# Какие у нас выводы?
# </div>

# %% [markdown]
# Потому что бинарные характеристики принимают только два значения (0 и 1), и их интерпретация в терминах среднего и медианы может быть менее информативной.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 3</b>&nbsp;⚠️<br>
# Медианы, действительно, считать тут имеет смысл лишь по балансу и доходам, как столбцам с выбросами.
#
# По средним всё очень информативно будет - среди отточных активные составляют столько-то процентов, а среди неактивных - столько-то, разница такая-то.
# </div>

# %%
median_value = data['balance'].median()
data_balance_high = data.query(f"{'balance'} > {median_value}")
data_balance_low = data.query(f"{'balance'} <= {median_value}")

# %%
churn_counts = data_balance_high['churn'].value_counts(dropna=False)
plt.figure(figsize=(6, 6))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Распределение таргет-переменной churn')
plt.show()

# %%
churn_counts = data_balance_low['churn'].value_counts(dropna=False)
plt.figure(figsize=(6, 6))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Распределение таргет-переменной churn')
plt.show()

# %% [markdown]
# Видим, что доля ушедших больше у тех, у кого баланс больше медианы

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>
# Опять с точностью до наоборот
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Не исправлен неверный вывод.
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# Рассмотрим гипотезу: чем меньше баланс, тем больше доля ушедших; рассмотрим граничное значение как половина медианы

# %%
median_value_new = median_value / 2
data_balance_low = data.query(f"{'balance'} <= {median_value_new}")

churn_counts = data_balance_low['churn'].value_counts(dropna=False)
plt.figure(figsize=(6, 6))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Распределение таргет-переменной churn')
plt.show()

# %%
median_value_new_new = median_value_new / 2
data_balance_low = data.query(f"{'balance'} <= {median_value_new_new}")

churn_counts = data_balance_low['churn'].value_counts(dropna=False)
plt.figure(figsize=(6, 6))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Распределение таргет-переменной churn')
plt.show()

# %% [markdown]
# Делаем вывод, что гипотеза неверна

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# Не стоит каждый раз выводить пироговую диаграмму. Если ты хочешь посмотреть уровни оттока в каждой из групп, если разделить баланс на какое-то число равных по размеру групп, то лучше смотреть так:
# </div>

# %%
### КОД РЕВЬЮЕРА

data.assign(bal_gr = pd.qcut(data.balance,16,precision=-5)\
                        .cat.add_categories("NaN")\
                        .fillna('NaN'))\
    .groupby('bal_gr').agg({'churn':"mean"})\
    .plot(kind='barh',figsize=(6,10)).axvline(data.churn.mean(),c='r');

# %% [markdown]
# Рассмотрим распределение по гендеру

# %%
churn_counts = data['gender'].value_counts(dropna=False)
plt.figure(figsize=(6, 6))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Распределение гендера')
plt.show()

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;⚠️<br>
# Неверный заголовок.
# </div>

# %% [markdown]
# Количество мужчин и женщин примерно одинаково, но теперь посмотрим распределение таргета с учетом гендера

# %%
plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
sns.countplot(data=data, x='gender', hue='churn')
plt.title("Churn Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(title="Churn", loc='upper right')
plt.show()

# %% [markdown]
# Видим, что мужчины в среднем чаще уходят

# %%
categorical_columns = [col for col in data.columns if data[col].nunique() < 15 and col != 'churn']

average_churn_rate = data['churn'].mean()

for col in categorical_columns:
    churn_by_category = data.groupby(col)['churn'].mean()
    
    plt.figure(figsize=(10, 6))
    sns.barplot(x=churn_by_category.index, y=churn_by_category.values)
    plt.axhline(y=average_churn_rate, color='r', linestyle='--', label='Средний уровень оттока')
    plt.title(f'Уровень оттока по категории: {col}')
    plt.xlabel(col)
    plt.ylabel('Уровень оттока')
    plt.xticks(rotation=45)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Уровень оттока мужчин выше среднебанковского
#
# Оттток людей без кредита выше среднебанковского
#
# Отток с quity 3 и выше больше среднебанковского
#
# В городах Ростов и Ярославль отток больше среднебанковского
#
# Отток с продуктами 2 и выше больше среднебанковского
#
# Отток у активных людей больше среднебанковского

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Пожалуйста, по категориальным переменным (для наших целей мы можем считать таковыми все у которых менее 15 уникальных значений) посчитай при помощи groupby или pivot_table уровень оттока и отобрази его на столбиковых диаграммах. Также при помощи plt.axvline или plt.axhline отобрази на этих графиках средний уровень оттока по банку.
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b> графики построены</div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>График по продуктам испорчен аномалией.
#
# Какие из этих графиков следуют выводы?
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 3</b>&nbsp;🔧<br>
# По городам, активности, по продуктам выводов нет, а они нам нужны.
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 4&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# Теперь построим тепловую карту корреляций, чтобы посмотреть какие из числовых переменных сильнее всего влияют на нашу целевую переменную

# %%
from scipy.stats import chi2_contingency
import pandas as pd

# Функция для интерпретации корреляций по шкале Чеддока
def interpret_correlation(correlation):
    if correlation <= 0:
        return "Зависимость отсутствует"
    elif 0 < correlation <= 0.3:
        return "Очень слабая связь"
    elif 0.3 < correlation <= 0.5:
        return "Слабая связь"
    elif 0.5 < correlation <= 0.7:
        return "Средняя связь"
    elif 0.7 < correlation <= 0.9:
        return "Высокая связь"
    elif 0.9 < correlation <= 1:
        return "Очень высокая связь"
    else:
        return "Некорректное значение корреляции"


# Отображение корреляционной тепловой карты для числовых переменных
correlation_matrix = data[numeric_features + ['churn']].corr()
plt.figure(figsize=(10, 8))
sns.set(style="white")
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap of Numeric Features and Churn")
plt.show()

# Анализ зависимостей с корреляцией >= 0.1 для числовых переменных
threshold = 0.1
significant_correlations = correlation_matrix[np.abs(correlation_matrix['churn']) >= threshold]['churn']
significant_correlations = significant_correlations.drop('churn')  # Убрать корреляцию с самим собой

# Вывод значимых корреляций для числовых переменных
print("Корреляции для числовых переменных:")
for feature, correlation in significant_correlations.items():
    relation = interpret_correlation(correlation)
    print(f"Зависимость между churn и {feature}: {relation}, корреляция: {correlation:.2f}")

# Создаем категориальные переменные для анализа
categorical_features = ['city', 'gender']

# Создаем пустой словарь для хранения значимых корреляций
significant_correlations = {}

# Анализ зависимостей с помощью коэффициента корреляции Крамера для категориальных переменных
for feature in categorical_features:
    contingency_table = pd.crosstab(index=data[feature], columns=data['churn'])
    
    # Выполняем тест хи-квадрат для определения корреляции
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    
    # Вычисляем коэффициент корреляции Крамера
    n = contingency_table.sum().sum()  # Общее количество наблюдений
    phi2 = chi2 / n
    correlation = max(0, (phi2 - ((len(contingency_table) - 1) * (len(contingency_table.columns) - 1))) / (n - (len(contingency_table) - 1) * (len(contingency_table.columns) - 1)))
    correlation = round(correlation**0.5, 2)
    
    significant_correlations[feature] = correlation

# Вывод значимых корреляций для категориальных переменных
print("\nКорреляции для категориальных переменных:")
for feature, correlation in significant_correlations.items():
    relation = interpret_correlation(correlation)
    print(f"Зависимость между churn и {feature}: {relation}, корреляция: {correlation:.2f}")
# Out:
# Корреляции для числовых переменных:
# Зависимость между churn и score: Очень слабая связь, корреляция: 0.10
# Зависимость между churn и equity: Очень слабая связь, корреляция: 0.27
# Зависимость между churn и products: Очень слабая связь, корреляция: 0.30
#
# Корреляции для категориальных переменных:
# Зависимость между churn и city: Зависимость отсутствует, корреляция: 0.00
# Зависимость между churn и gender: Зависимость отсутствует, корреляция: 0.00

# %% [markdown]
# <div class="alert alert-danger"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Не рассчитана корреляция уровня оттока с бинарными характеристиками, включая пол, а также с признаком городов.
#
# Пожалуйста, опиши все зависимости между оттоком и другими признаками по шкале Чеддока (принимая во внимание корреляции по модулю равные или более 10%).
# </div>

# %% [markdown]
# <div class="alert alert-danger"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Не нужно учитывать корреляции от -10% до 10% исключительно. Нужно только то, что больше или равно 10% по модулю. Нужно посмотреть корреляции со всеми характеристиками.
# </div>

# %% [markdown]
# <div class="alert alert-danger"><b>Комментарий ревьюера 3</b>&nbsp;🔴<br>
# Не исправлено. Если тебе неясны мои комментарии выше и что нужно сделать, пожалуйста, задай вопрос в канале в Пачке.
# </div>

# %% [markdown]
# <div class="alert alert-danger"><b>Комментарий ревьюера 4</b>&nbsp;🔴<br>
# Всё ещё не рассчитана корреляция оттока с городами, с полом. Корреляции не описаны по шкале Чеддока.
# </div>

# %% [markdown]
# Также построим распределения непрерывных признаков в разрезе оттока

# %%
plt.figure(figsize=(18, 12))
sns.set(style="whitegrid")

numeric_features_to_plot = [feature for feature in numeric_features if feature not in ['products', 'equity']]

for idx, feature in enumerate(numeric_features_to_plot, start=1):
    plt.subplot(2, 3, idx)
    
    if feature == 'balance':
        not_churn_balances = data[data['churn'] == 0][feature]
        churn_balances = data[data['churn'] == 1][feature]
        plt.xlim(0, 0.2 * 1e8)
    else:
        not_churn_balances = data[data['churn'] == 0][feature]
        churn_balances = data[data['churn'] == 1][feature]
    
    sns.histplot(data=not_churn_balances, bins=20, kde=True, label='Not Churn', stat='density', common_norm=False)
    sns.histplot(data=churn_balances, bins=20, kde=True, label='Churn', stat='density', common_norm=False)
    
    plt.title(f"Distribution of {feature} by Churn")
    plt.xlabel(feature)
    plt.ylabel("Density")
    plt.legend(title="Churn")

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Пожалуйста, чтобы точно сделать корректные выводы, примени следующие параметры тут:
#
#     kde=True, stat='density', common_norm=False
#
# Также, пожалуйста, увеличь размер каждого из графиков и убери следующий параметр:
#
#     multiple='stack'
#
# Когда мы выделяем отточные сегменты, мы выделяем как отточных, так и не отточных клиентов по каким-то признакам. Поэтому более отточные интервалы мы не можем определить просто по анализу распределения отточных. Мы не должны игнорировать распределение неотточных, однако, так как датасет несбалансированный, сделать какие-то выводы по ненормированным графикам действительно сложно.
#
# Нас интересуют участки характеристик, на которых уровень оттока превышает средний по банку. Делать группировку по характеристикам с большим количеством уникальных значений (баланс, зарплата) напрямую нельзя и поэтому сложно, но мы можем сделать этот вывод и по нормализованным гистограммам или kde-графикам. Уровень оттока приблизительно будет превышать средний по банку там, где плотность распределения отточных клиентов будет выше плотности распределения неотточных (можно сказать, что нормированная гистограмма показывает нам, как выглядели бы распределения отточных и неотточных, если бы их в датасете было равное количество).
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b> Графики (за исключением баланса) позволяют делать выводы.</div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Выводы о том, какие именно интервалы характеристик связаны с повышенным оттоком не сделаны.
# </div>

# %% [markdown]
# Отток score наибольший на интервале с 820 до 940
#
# Отток age наибольший на интервале с 25 до 35
#
# Отток est_salary наибольший на интервале 100000 - 200000 рублей
#
# Отток balance наибольший на интервале от 0 до 3000000 рублей

# %% [markdown]
# Видим, что наибольшую свзяь *churn* имеет с *products*, *equity* и *score*, рассмотрим более подробно

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b> по скору и возрасту ок</div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 3</b>&nbsp;🔧<br>
# Что такое 0.1-0.2 дохода? 0.3 баланса? Сколько это в тех единицах измерения, в которых построен график? Аналитик должен уметь читать экспоненциальную запись.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 4</b>&nbsp;🔴<br>
# Ты аналитик и должен понимать экспоненциальную запись (1e6 обозначает 1 * 10 ^ 6 - т.е. 10 в шестой степени), а вот от менеджеров, которым могут показать твою работу, мы этого ожидать не можем, пожалуйста, укажи суммы полностью в рублях или в тысячах и миллионах.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 5</b>&nbsp;⛔️<br>
# Всё верно, кроме баланса. Но там график не позволил сделать выводы верные
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>Нужно будет особое внимание обратить на график по балансу (по продуктам и по баллам собственности лучше такого типа графики не делать).
#
# Чтобы график характеристики с выбросами был читаем и корректен необходимо либо к данным применить метод <tt>.clip(0,<верхняя граница>)</tt>, либо к графику применить <tt>plt.xlim</tt>.
#
# В случае если график строится в цикле, можно использовать if, либо сделать ещё один график ниже.
#
# При анализе этого и других графиков нужны выводы вида: По данной характеристике отточные интервалы с ___ до ___ (и с ___ до ____). Речь при этом должна идти не про само распределение отточных, а о превышении распределения отточных над распределением неотточных в ситуации, если бы их в банке было поровну.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Не отработано. График по балансу нечитаем.
#
# Гистограммы по продуктам и баллам собственности не нужны, по ним есть графики с уровнями оттока.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 3</b>&nbsp;⚠️<br>
# Ок, уже сильно лучше, но всё еще "bins=20" не хватает для хорошего графика по балансу.
# </div>

# %%
proportions = data.groupby(['products', 'churn']).size() / len(data)

proportions = proportions.reset_index(name='proportion')

plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
sns.barplot(data=proportions, x='products', y='proportion', hue='churn')
plt.title("Churn Distribution by Products")
plt.xlabel("Products")
plt.ylabel("Proportion")
plt.legend(title="Churn", loc='upper right')
plt.show()

# %%
display('Распределение продуктов')
display(data['products'].value_counts())

unique_products = proportions['products'].unique()


for product in unique_products:
    plt.figure(figsize=(6, 6))
    plt.title(f"Churn Distribution for Product {product}")
    product_data = proportions[proportions['products'] == product]
    plt.pie(product_data['proportion'], labels=product_data['churn'], autopct='%1.1f%%', startangle=140)
    plt.axis('equal')
    plt.show()
# Out:
# 'Распределение продуктов'
# 2    5070
# 1    3288
# 3    1021
# 4     457
# Name: products, dtype: int64

# %% [markdown]
# Видим закономерность, что чем больше продуктов у клиента, тем меньше его шанс остаться.
# Если больше 2 продуктов то клиент уйдет в отток.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Пожалуйста укажи начиная с какого числа продуктов у нас вероятность что клиент уйдёт в отток выше среднебанковской.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Всё ещё путаем в проекте что значит отток 1 и 0. Сделаны выводы с точностью до наоборот.
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# Попробуем еще использовать признак *gender*

# %%
proportions = data.groupby(['gender', 'products', 'churn']).size() / len(data)

proportions = proportions.reset_index(name='proportion')

unique_genders = proportions['gender'].unique()
unique_products = proportions['products'].unique()

for gender in unique_genders:
    for product in unique_products:
        plt.figure(figsize=(6, 6))
        plt.title(f"Churn Distribution for Gender {gender} and Product {product}")
        subset_data = proportions[(proportions['gender'] == gender) & (proportions['products'] == product)]
        plt.pie(subset_data['proportion'], labels=subset_data['churn'], autopct='%1.1f%%', startangle=140)
        plt.axis('equal')
        plt.show()

# %% [markdown]
# Видим, что у женщин с количеством продуктов 1 остаются всего 4.2%, а у мужчин - 9.5%, тогдав выдвинем две гипотезы:
# 1. Мужчины с 1 продуктом уходят чаще
# 2. Женщины с 1 продуктом уходят чаще
#
# Проверять будем гипотезы с помощью t-теста на уровне значимости 0.05

# %%
sample_women = data[(data['gender'] == 'Ж') & (data['products'] == 1)]['churn']
sample_men = data[(data['gender'] == 'М') & (data['products'] == 1)]['churn']

t_statistic_women, p_value_women = ttest_ind(sample_women, data['churn'])
t_statistic_men, p_value_men = ttest_ind(sample_men, data['churn'])

print(f"T-statistic for women: {t_statistic_women}")
print(f"P-value for women: {p_value_women}")
print(f"T-statistic for men: {t_statistic_men}")
print(f"P-value for men: {p_value_men}")
# Out:
# T-statistic for women: -13.726408203045537
# P-value for women: 1.5418057445636327e-42
# T-statistic for men: -8.837318260472623
# P-value for men: 1.1211174899431367e-18

# %% [markdown]
# Гипотеза подтвержается, делаем вывод: как женщины так и мужчины, имеющие 1 продукт больше склонны к уходу, чем пользователи, у которых больше 1 продукта

# %% [markdown]
# Теперь более подробно рассмотрим признак *equity*

# %%
proportions = data.groupby(['equity', 'churn']).size() / len(data)

proportions = proportions.reset_index(name='proportion')

plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
sns.barplot(data=proportions, x='equity', y='proportion', hue='churn')
plt.title("Churn Distribution by Equity")
plt.xlabel("Equity")
plt.ylabel("Proportion")
plt.legend(title="Churn", loc='upper right')
plt.show()

# %%
display('Распределение оценки собственности')
display(data['equity'].value_counts())

unique_equities = proportions['equity'].unique()

for equity in unique_equities:
    plt.figure(figsize=(6, 6))
    plt.title(f"Churn Distribution for Equity {equity}")
    equity_data = proportions[proportions['equity'] == equity]
    plt.pie(equity_data['proportion'], labels=equity_data['churn'], autopct='%1.1f%%', startangle=140)
    plt.axis('equal')
    plt.show()
# Out:
# 'Распределение оценки собственности'
# 0    2538
# 5    1886
# 4    1817
# 3    1523
# 2    1041
# 1     767
# 6     157
# 7      77
# 8      17
# 9      13
# Name: equity, dtype: int64

# %% [markdown]
# Если число баллов равно 3 и выше то вероятность что клиент уйдет в отток выше среднебанковской
# Для остальных баллов собственности можно провести аналогичный анализ. Если вероятность ухода в отток выше среднебанковской то это может указывать на то, что клиенты в этом диапазоне баллов также имеют факторы, связанные с уходом в отток. В противном случае, если вероятность ухода в отток ниже среднебанковской, это может свидетельствовать о том, что клиенты с такими баллами собственности более лояльны и менее склонны к уходу.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Пожалуйста укажи начиная с какого числа баллов собственности у нас вероятность что клиент уйдёт в отток выше среднебанковской.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
#
# ! [image.png](attachment:image.png)
#
# А для остальных баллов собственности какие выводы?
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# Аналогично признаку *products* сделаем еще распределение по гендеру

# %%
data_copy = data.copy()

equity_order = data_copy['equity'].value_counts().index

plt.figure(figsize=(12, 8))
sns.barplot(data=data_copy, x='equity', y='churn', hue='gender', order=equity_order)
plt.title("Churn Distribution by Gender and Equity")
plt.xlabel("Equity")
plt.ylabel("Churn Rate")
plt.xticks(rotation=45)
plt.legend(title="Gender")
plt.show()

# %% [markdown]
# Выдвигаем гипотезы:
# 1. У женщин с equity 7 доля уходов значительно больше
# 2. У женщин с equity 8 доля уходов значительно больше
# 3. У женщин с equity 9 доля уходов значительно больше
# 4. У мужчин с equity 7 доля уходов значительно больше
# 5. У мужчин с equity 8 доля уходов значительно больше
# 6. У мужчин с equity 9 доля уходов значительно больше

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫 <s>тут опять отточные и неотточные перепутаны, кажется.</s>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;⚠️<br>
# Выше бесполезное для нас исследование. Пироговых диаграмм слишком много, выводы слишком очевидны. Если хочешь исследовать отдельно женщин и мужчин в разрезе количества продуктов, то лучше подойдут графики как выше, когда каждый балл одним столбиком, а не одной пироговой диаграммой отображается.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>
# Перед тем, как делать стат. тест, нужно сформулировать гипотезу или гипотезы. Должно быть настроено автоматическое сравнение с уровнем значимости.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Не исправлено. Какие гипотезы проверяются ниже, не указано. Автоматическая проверка не настроена.
# </div>

# %% [markdown]
# Нулевая гипотеза (H0): Нет статистически значимой разницы в оттоке между группами с разными значениями пола и equity (соблюдение оттока не зависит от пола и уровня equity).
#
# Обратная гипотеза (H1): Существует статистически значимая разница в оттоке между группами с разными значениями пола и equity (соблюдение оттока зависит от пола и уровня equity).

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# Проверять гипотезы будем с помощью t-теста на уровне значимости 0.05

# %%
equity_values = [1,2,3,4,5,6,7, 8, 9]
gender_values = ['Ж', 'М']  # Список значений пола

alpha = 0.05 / (len(equity_values) * len(gender_values))  # Коррекция уровня значимости

for equity in equity_values:
    for gender in gender_values:
        sample = data[(data['gender'] == gender) & (data['equity'] == equity)]['churn']
        total = data[data['equity'] == equity]['churn']

        t_statistic, p_value = ttest_ind(sample, total)

        if p_value < alpha:
            print(f"Отвергаем нулевую гипотезу: Существует статистически значимая разница для Пол: {gender}, Equity: {equity}, p-value = {p_value:.4f}")
        else:
            print(f"Не отвергаем нулевую гипотезу: Нет статистически значимой разницы для Пол: {gender}, Equity: {equity}, p-value = {p_value:.4f}")
# Out:
# Не отвергаем нулевую гипотезу: Нет статистически значимой разницы для Пол: Ж, Equity: 1, p-value = 0.0127
# Не отвергаем нулевую гипотезу: Нет статистически значимой разницы для Пол: М, Equity: 1, p-value = 0.0229
# Не отвергаем нулевую гипотезу: Нет статистически значимой разницы для Пол: Ж, Equity: 2, p-value = 0.0357
# Не отвергаем нулевую гипотезу: Нет статистически значимой разницы для Пол: М, Equity: 2, p-value = 0.0358
# Отвергаем нулевую гипотезу: Существует статистически значимая разница для Пол: Ж, Equity: 3, p-value = 0.0001
# Отвергаем нулевую гипотезу: Существует статистически значимая разница для Пол: М, Equity: 3, p-value = 0.0001
# Отвергаем нулевую гипотезу: Существует статистически значимая разница для Пол: Ж, Equity: 4, p-value = 0.0000
# Отвергаем нулевую гипотезу: Существует статистически значимая разница для Пол: М, Equity: 4, p-value = 0.0000
# Отвергаем нулевую гипотезу: Существует статистически значимая разница для Пол: Ж, Equity: 5, p-value = 0.0000
# ...

# %% [markdown]
# Для мужчин и женщин и equity от 3 до 5 включительно значение p-value меньше уровня значимости, что означает, что есть статистически значимые различия в оттоке между группами. В данном случае отвергается нулевая гипотеза, которая гласит, что различий в оттоке между группами нет.
#
# Для мужчин и женщин и equity от 1 до 2 и от 6 до 9 значение p-value больше уровня значимости, что означает отсутствие статистически значимых различий в оттоке между группами. В этом случае не отвергается нулевая гипотеза.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 3</b>&nbsp;⚠️<br>
# В гипотезах ты не ограничиваешь группы только значениями equity 7-9.
#
# Если бы прокрасился хотя бы один тест — ты бы сделал вывод о различии, возможно ошибочный, т.к. не применяешь поправку на множественную проверку.
# </div>

# %% [markdown]
# Делаем выводы: у женщин и мужчин с *equity* равное 9 наблюдается churn 0 чаще, также у женщин с equity равным 8 и 7

# %% [markdown]
# Рассмотрим более подробно признак *score*

# %%
score_bins = range(0, 1050, 50)
data['score_bins'] = pd.cut(data['score'], bins=score_bins, labels=[f'{i}-{i+50}' for i in range(0, 1000, 50)])

proportions_score = data.groupby(['score_bins', 'churn']).size() / len(data)
proportions_score = proportions_score.reset_index(name='proportion')

plt.figure(figsize=(15, 6))
sns.set(style="whitegrid")
sns.barplot(data=proportions_score, x='score_bins', y='proportion', hue='churn')
plt.title("Churn Distribution by Score Intervals (Step 50)")
plt.xlabel("Score Intervals")
plt.ylabel("Proportion")
plt.legend(title="Churn", loc='upper right')
plt.xticks(rotation=45)
plt.show()

# %%
display(data['score'].min())
display(data['score'].max())
# Out:
# 642.0
# 1000.0

# %% [markdown]
# Видим, что значения *score* начинаются с 642, тогда сделаем более информативный график

# %%
# Создание KDE-графика
plt.figure(figsize=(10, 6))
sns.kdeplot(data=data, x='score', hue='churn', common_norm=False, fill=True)
plt.title("KDE Plot of Scores with Churn Comparison")
plt.xlabel("Score")
plt.ylabel("Density")
plt.legend(title="Churn")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Самы большой отток на промежутке с 820 до 940

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🚫<br>
# Ошибка в коде
#
#     ----> 3 sns.kdeplot(data=data, x='score', hue='churn', common_norm=False, fill=True, palette=sns.color_palette("pastel"))
#
# ![image.png](attachment:image.png)
#
# Решается удалением обёртки "sns.color_palette()"
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# У нас разное число отточных и неотточных, стоит смотреть либо уровень оттока в каждой из категорий и сравнивать со среднебанковской, либо смотреть нормированную гистограмму или kde-график. Из графика как выше точные выводы сделать сложно.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;⚠️<br>
# Выше про это уже есть красный комментарий, поэтому жёлтым. Какие выводы у нас из графика выше?
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %%
score_bins = range(640, 1060, 30)
data['score_bins'] = pd.cut(data['score'], bins=score_bins, labels=[f'{i}-{i+30}' for i in range(640, 1030, 30)])

sorted_bins = sorted(data['score_bins'].unique(), key=lambda x: int(x.split('-')[0]))

for score_bin in sorted_bins:
    subset_data = data[data['score_bins'] == score_bin]
    churn_counts = subset_data['churn'].value_counts()
    labels = ['0', '1']
    
    sizes = [churn_counts.get(0, 0), churn_counts.get(1, 0)]
    
    plt.figure(figsize=(6, 6))
    plt.title(f"Churn Distribution for Score Interval {score_bin}")
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.axis('equal')
    plt.show()

# %%
score_bins_order = sorted(data['score_bins'].unique(), key=lambda x: int(x.split('-')[0]))

plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='score_bins', hue='churn', order=score_bins_order, hue_order=[0, 1])
plt.title("Churn Distribution by Score Intervals")
plt.xlabel("Score Intervals")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.legend(title="Churn", labels=["Not Churned", "Churned"])
plt.show()

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# Стоит применить другой вид графика, кажется.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;⚠️<br>
# Пожалуйста не строй в цикле так много графиков, они слабоинформативны. Каждый из графиков выше может быть заменён одним столбиком на одном графике.
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# Видим, что доля людей, которые уходят увеличивается с увеличением *score*, самая большая на промежутке 820 - 940 и к концу спадает.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>
# <span class="alert-success">✔️ нашли отточный интервал от 820 до 940</span>
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Выводы не исправлены.
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# Нулевая гипотеза (H0):
# Признак score не оказывает статистически значимого влияния на отток клиентов в банке в промежутке 820 - 940.
#
# Альтернативная гипотеза (H1):
# Признак score имеет статистически значимое влияние на отток клиентов в банке в промежутке 820 - 940.

# %%
# Выделяем данные для промежутка 820 - 940
score_range_data = data[(data['score'] >= 820) & (data['score'] <= 940)]

# Разделяем данные на ушедших и оставшихся клиентов
churned_scores = score_range_data[score_range_data['churn'] == 1]['score']
not_churned_scores = score_range_data[score_range_data['churn'] == 0]['score']

# Выполняем t-тест Стьюдента
t_stat, p_value = ttest_ind(churned_scores, not_churned_scores, nan_policy='omit')

alpha = 0.05  # Уровень значимости

print("T-Test Results:")
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

if p_value < alpha:
    print("Отвергаем нулевую гипотезу: Признак score оказывает статистически значимое влияние на отток клиентов.")
else:
    print("Не отвергаем нулевую гипотезу: Признак score не оказывает статистически значимого влияния на отток клиентов.")
# Out:
# T-Test Results:
# T-statistic: -2.6695119578972117
# P-value: 0.007616968429517144
# Отвергаем нулевую гипотезу: Признак score оказывает статистически значимое влияние на отток клиентов.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔧<br>
# Перед тем, как делать проверку стат.тестом, нужно каждый раз формулировать нулевую и альтернативную гипотезы. При самой проверке устанавливать уровень стат.значимости до теста и проводить её автоматически.
#
# Тут как и выше неверная интерпретация.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %%
from statsmodels.stats.proportion import proportions_ztest

# Выборки и успехи для двух интервалов рейтинга
sample_range_1 = data[(data['score'] >= 640) & (data['score'] <= 820)]['churn']
successes_range_1 = sample_range_1.sum()

sample_range_2 = data[(data['score'] >= 940) & (data['score'] <= 1000)]['churn']
successes_range_2 = sample_range_2.sum()

# Общее количество клиентов в каждой группе
nobs_range_1 = len(sample_range_1)
nobs_range_2 = len(sample_range_2)

# Проведение теста на проверку долей
stat, p_value = proportions_ztest([successes_range_1, successes_range_2], [nobs_range_1, nobs_range_2])

# Уровень значимости
alpha = 0.05

print(f"Z-статистика: {stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Сравнение p-value с уровнем значимости и вывод результатов
if p_value < alpha:
    print("Есть статистически значимые различия в долях оттока между группами.")
else:
    print("Статистически значимых различий в долях оттока между группами не обнаружено.")
# Out:
# Z-статистика: -1.7722
# P-value: 0.0764
# Статистически значимых различий в долях оттока между группами не обнаружено.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔧<br>
# Мы имеем дело с бинарной характеристикой. Неверно по ней смотреть среднее (хотя тут настолько очевидны различия, что мы их обнаружили). Не всегда различия будут очевидны. Пожалуйста, повтори проверку при помощи теста на проверку долей. Есть его реализация в качестве отдельного метода: <a href='https://www.statsmodels.org/stable/generated/statsmodels.stats.proportion.proportions_ztest.html'>proportions_ztest</a>. Попытки у нас это числа по категориям, а успехи, это числа по категориям, которые при этом попадают в одну из групп.
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b> хороший подход</div>

# %% [markdown]
# ### Графики категориальных переменных переменных

# %% [markdown]
# У нас есть одна категориальная переменная *city*, рассмотрим ее поподробнее

# %%
data["city"].value_counts()
# Out:
# Ярославль    5802
# Рыбинск      2621
# Ростов       1413
# Name: city, dtype: int64

# %% [markdown]
# Всего 3 города Ярославль, Рыбинск и Ростов

# %%
city_churn_proportions = data.groupby(['city', 'churn']).size() / len(data)
city_churn_proportions = city_churn_proportions.reset_index(name='proportion')

plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")
sns.barplot(data=city_churn_proportions, x='city', y='proportion', hue='churn')
plt.title("Churn Distribution by City (Proportions)")
plt.xlabel("City")
plt.ylabel("Proportion")
plt.legend(title="Churn", loc='upper right')
plt.xticks(rotation=45)
plt.show()

# %%
unique_cities = data['city'].unique()

for city in unique_cities:
    subset_data = data[data['city'] == city]
    churn_counts = subset_data['churn'].value_counts()
    labels = ['0', '1']
    sizes = [churn_counts.get(0, 0), churn_counts.get(1, 0)]

    plt.figure(figsize=(6, 6))
    plt.title(f"Churn Distribution for City {city}")
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.axis('equal')
    plt.show()

# %% [markdown]
# Анализируя доли ушедших, видим, что никаких аномалий нет, распределение долей примерно одинаковое для каждого города, делаем вывод, что доля ушедших от города не зависит

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Пожалуйста проверь гипотезу о различии доходов в разрезе оттока, как описано в декомпозиции и сделай сегментацию.

# %% [markdown]
# Проверка гипотезы о различии доходов в разрезе оттока

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔧<br>
# Не сформулирована нулевая и альтернативная гипотезы.
# </div>

# %% [markdown]
# Нулевая гипотеза (H0): Средние доходы ушедших клиентов и оставшихся клиентов одинаковы.
#
# Альтернативная гипотеза (H1): Средние доходы ушедших клиентов и оставшихся клиентов различаются.

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %%
# Разделим данные на ушедших и оставшихся клиентов
churned_income = data[data['churn'] == 1]['est_salary']
not_churned_income = data[data['churn'] == 0]['est_salary']

# Выполним t-тест Стьюдента
t_stat, p_value = ttest_ind(churned_income, not_churned_income, nan_policy='omit')

alpha = 0.05  # Уровень значимости

print("T-Test Results:")
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

if p_value < alpha:
    print("Отвергаем нулевую гипотезу: Существует статистически значимая разница в доходах.")
else:
    print("Не отвергаем нулевую гипотезу: Нет статистически значимой разницы в доходах.")
# Out:
# T-Test Results:
# T-statistic: -0.10748560769411811
# P-value: 0.9144059352462982
# Не отвергаем нулевую гипотезу: Нет статистически значимой разницы в доходах.

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2</b>&nbsp;✔️<br>
# Есть автоматическая проверка результатов.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔧<br>
# Пожалуйста, повтори эту проверку ниже при помощи u-критерия Манна-Уитни, если между методами возникнет разница, прокомментируй, почему она возникла. Какой критерий тут будет точнее и почему?
# </div>

# %%
from scipy.stats import mannwhitneyu

# Разделим данные на ушедших и оставшихся клиентов
churned_income = data[data['churn'] == 1]['est_salary']
not_churned_income = data[data['churn'] == 0]['est_salary']

# Выполним U-критерий Манна-Уитни
stat, p_value_mann = mannwhitneyu(churned_income, not_churned_income, alternative='two-sided')

print("Mann-Whitney U-Test Results:")
print(f"Statistic: {stat}")
print(f"P-value: {p_value_mann}")

alpha = 0.05

if p_value_mann < alpha:
    print("Отвергаем нулевую гипотезу: Существует статистически значимая разница в доходах.")
else:
    print("Не отвергаем нулевую гипотезу: Нет статистически значимой разницы в доходах.")
# Out:
# Mann-Whitney U-Test Results:
# Statistic: 7480391.0
# P-value: 0.0006732494992441395
# Отвергаем нулевую гипотезу: Существует статистически значимая разница в доходах.

# %% [markdown]
# Тест Стьюдента (t-тест) предполагает, что данные имеют нормальное распределение и имеют равные дисперсии. Если эти предположения выполняются, t-тест может быть более мощным, то есть более способным обнаруживать статистически значимые различия в данных.
#
# С другой стороны, U-критерий Манна-Уитни является непараметрическим тестом и не делает предположений о нормальности распределения данных. Он основан на рангах данных и может быть менее мощным, но более устойчивым к выбросам и отклонениям от нормальности.
#
# В вашем случае, разница в результатах может быть обусловлена тем, что данные о доходах могут не иметь нормального распределения, и U-критерий Манна-Уитни, который не требует такого предположения, может быть более подходящим.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 3</b>&nbsp;📌<br>
# Так как выборки большие, то нам неважно, что они распределены ненормально, мы можем использовать t-критерий. Требование нормальности распределения происходит из медицинской литературы, где традиционно маленькие выборки.
#
# <blockquote>Выборочные средние должны быть нормально распределены.
# А если выборка всего одна, то её среднее должно иметь нормальное распределение для разных выборок этого размера из определённой генеральной совокупности.
# Это условие не препятствие. Благодаря ЦПТ, если размер выборки составляет хотя бы несколько десятков значений, выборочные средние, которые можно получить из одной и той же генеральной совокупности, будут распределены нормально вокруг истинного среднего этой совокупности. Напомним, это утверждение верно, даже если сама генеральная совокупность не распределена нормально.
#
# Очень часто это условие путают с необходимостью нормального распределения самих генеральных совокупностей. Для корректного использования t-теста это необязательно.</blockquote>
# Таким образом нормальное распределение для выборок более 30-50 элементов не требуется для t-теста. Требуется отсутствие большого числа выбросов, так как это не робастный критерий. Но выбросы можно отфильтровать.
#
# При разном размере выборок, который нам тут известен мы ставим equal_var в положение False просто из-за особенностей работы метода ttest_ind. И вообще, надёжнее при любых сомнениях ставить его в это положение, это лишь немного снижает мощность данного стат критерия. В среднем у u-критерия Манна-Уитни мощность выше, чем у t-критерия, т.е. он чаще даёт более точный результат. В литературе встречаются утверждения, что его нельзя проводить, если есть значительное число повторяющихся значений или если выборки большие, однако это относится, видимо, к старым реализациям теста.
#
# Основной минус критерия Манна-Уитни — его слабая интерпретируемость для бизнеса. Если мы сраниваем суммы покупок, то t-критерий позволяет нам сравнить средний чек — величину, которую можно перевести в выручку, умножив на количество покупок. U-критерий же, по сути, будет сравнивать медианный чек, который практически не используется.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔧<br>
# Для проверок ниже не сформулированы нулевые и альтернативные гипотезы.
# </div>

# %% [markdown]
# Нулевая гипотеза (H0): Средние доходы ушедших и оставшихся клиентов в данном городе одинаковы.
#
# Альтернативная гипотеза (H1): Средние доходы ушедших и оставшихся клиентов в данном городе различаются.

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %%
city_segments = data['city'].unique()

for city in city_segments:
    city_churned_income = data[(data['city'] == city) & (data['churn'] == 1)]['est_salary']
    city_not_churned_income = data[(data['city'] == city) & (data['churn'] == 0)]['est_salary']
    
    t_stat_city, p_value_city = ttest_ind(city_churned_income, city_not_churned_income, nan_policy='omit')
    
    print(f"City: {city}")
    print(f"T-Test Results:")
    print(f"T-statistic: {t_stat_city}")
    print(f"P-value: {p_value_city}")

    if p_value_city < alpha:
        print("Отвергаем нулевую гипотезу: Существует статистически значимая разница в доходах.")
    else:
        print("Не отвергаем нулевую гипотезу: Нет статистически значимой разницы в доходах.")
# Out:
# City: Рыбинск
# T-Test Results:
# T-statistic: -0.28208703682223707
# P-value: 0.7778990612796342
# Не отвергаем нулевую гипотезу: Нет статистически значимой разницы в доходах.
# City: Ярославль
# T-Test Results:
# T-statistic: -0.8441874554346194
# P-value: 0.39859948049550287
# Не отвергаем нулевую гипотезу: Нет статистически значимой разницы в доходах.
# City: Ростов
# T-Test Results:
# T-statistic: 3.0810688618401625
# P-value: 0.002102480505513604
# Отвергаем нулевую гипотезу: Существует статистически значимая разница в доходах.

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2</b>&nbsp;✔️<br>
# Есть автоматическая проверка результатов.
# </div>

# %% [markdown]
# ## Вывод

# %% [markdown]
# Выделенные сегменты, в которых отток клиентов наибольший:
# 1. Люди, неимеющие информацию в столбце balance
# 2. Люди с одним продуктом уходят чаще
# 3. Женщины с equity ниже 3
# 4. Мужчины с equity 0
# 5. Люди, у которых score находится на интервалах 640-820 и 940-1000

# %% [markdown]
# | Показатель | Сравнение портретов/гипотезы | Корреляции | Распределения в разрезе оттока |
# | :--- | :---: | :---: | :--- |
# | USERID | - | - | - |
# | score | на 2.10% | Корреляция с оттоком: 0.1047  | с 820 до 940 |
# | city | Нет существенных различий в оттоке между городами | - | - |
# | gender | Нет существенных различий в оттоке между гендерами | - | мужчины |
# | age | на 3.68% | Найдена отрицательная корреляция с age | с 25 до 35 |
# | equity | на 58.43% | Корреляция с оттоком: 0.2698 | с 2 до 10 |
# | balance | на 54.23% | - | с 0 до 0,30 *1е7 |
# | products | на 34.93% | Корреляция с оттоком: 0.3020  | с 2 |
# | credit_card | Нет существенных различий в оттоке | - | без кредитной карты |
# | last_activity | Нет существенных различий в оттоке | - | - |
# | est_salary | на 0.34% | - | 0,1 - 0,3 *1е5 |

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>Выше не все характеристики.
#
# Подведи, пожалуйста, итоги всему EDA. Ниже пример, как это можно сделать систематичным образом. Не обязательно заполнять такую таблицу (можно сделать это вручную), важно просто по каждому параметру установить, схожий или нет показали результат все разные подходы, которые мы пробовали и свести все отточные интервалы в одно место, чтобы удобно было потом делать сегментацию.
#
# |Показатель |Сравнение портретов/гипотезы|Корреляции|Распределения в разрезе оттока|
# | :--- | :---: | :---: | :--- |
# |неизвестный 1|есть связь         |нет связи | отточный интервал с __ по __ |
# |неизвестный 2|не может быть связи         | |  |
#
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# Последний столбец просьба заполнять по образцу, ты указываешь до таблицы неверные выводы, но по форме, например для скора, эти выводы подходят для таблицы. Для бинарных характеристик - пол, активность, кредитка, просто указать, кто уходит чаще - те, кто с кредиткой или без неё.
#
# В столбце Сравнение портретов укажи на сколько процентов отличается характеристика отточного от характеристики неотточного - ты это выше считал.
#
# В столбце "корреляции" - просто дополнить тем, что в промежуток от 10% до 20% попало.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Пожалуйста <s>проверь гипотезу о различии доходов в разрезе оттока, как описано в декомпозиции</s> и <u>сделай сегментацию</u>.
#
# Рекомендации стоит давать таргетировано. Рекомендация вида "ввести ограничение на оценку собственности" для нашего банка неисполнима.
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 3&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# <s>Не исправлено. Присутствуют явно ошибочные утверждения, о которых были комментарии (перепутаны отточные и неотточные). Если у тебя выделено пять сегментов, то ты должен посмотреть их характеристики и давать рекомендации по ним. Сначала делаем сегментацию, выделяя отточные сегменты (можешь пользоваться кодом ниже), потом даём рекомендации.
# </div>

# %%
data.sample()
# Out:
#       user_id  score    city gender   age  equity   balance  products  \
# 4558   172935  864.0  Ростов      М  28.0       0  153644.7         2
#
#       credit_card  last_activity  est_salary  churn  age_missing  \
# 4558            1              1    30751.42      1            0
#
#       balance_missing  gender_encoded  city_Рыбинск  city_Ярославль score_bins
# 4558                0               1             0               0    850-880

# %%
### КОД РЕВЬЮЕРА
df=data.copy()

qrys = (
    #'score >= 820 & score <= 940 & age >= 25 & age <= 35', # Высокие баллы "score" (820-940) и возраст от 25 до 35 лет.
    #'score >= 820 & score <= 940 & equity > 2', # Высокие баллы "score" и собственность от 2 до 10.
    #'score >= 820 & score <= 940 & balance > 0 & balance <= 3000000', # Высокие баллы "score" и баланс от 0 до 0,30 * 1е7.
 ##   'score >= 820 & score <= 940 & products > 2', # Высокие баллы "score" и наличие 2 продуктов.
    #'score >= 820 & score <= 940 & est_salary >= 10000 & est_salary <= 30000', # Высокие баллы "score" и зарплата от 0,1 до 0,3 * 1е5.
    #'age >= 25 & age <= 35 & equity > 2 ', # Возраст от 25 до 35 лет и собственность от 2 до 10.
    #'age >= 25 & age <= 35 & balance >= 0 & balance <= 3000000', # Возраст от 25 до 35 лет и баланс от 0 до 0,30 * 1е7.
    #'age >= 25 & age <= 35 & products > 2', # Возраст от 25 до 35 лет и наличие 2 продуктов.
    #'equity > 2 & balance >= 0 & balance <= 3000000', # Собственность от 2 до 10 и баланс от 0 до 0,30 * 1е7.
 ##   'equity > 2 & products > 2', # Собственность от 2 до 10 и наличие 2 продуктов.
   # 'balance >= 0 & balance <= 3000000 & products > 2', # Баланс от 0 до 0,30 * 1е7 и наличие 2 продуктов.
    #'age >= 25 & age <= 35 & gender == "М"', # Возраст от 25 до 35 лет и мужчины.
    #'equity > 2 & gender == "М"', # Собственность от 2 до 10 и мужчины.
    'products > 2 & gender == "М"', # Наличие 2 продуктов и мужчины.
    #'balance >= 0 & balance <= 3000000 & gender == "М"', # Баланс от 0 до 0,30 * 1е7 и мужчины.
 ##   'equity > 2 & balance >= 0 & balance <= 3000000 & products > 2', # Собственность от 2 до 10, баланс от 0 до 0,30 * 1е7 и наличие 2 продуктов.
    #'age >= 25 & age <= 35 & balance >= 0 & balance <= 3000000 & products > 2', # Возраст от 25 до 35 лет, баланс от 0 до 0,30 * 1е7 и наличие 2 продуктов.
   # 'age >= 25 & age <= 35 & equity > 2 & balance >= 0 & balance <= 3000000', # Возраст от 25 до 35 лет, собственность от 2 до 10, баланс от 0 до 0,30 * 1е7.
   # 'age >= 25 & age <= 35 & equity > 2 & products > 2', # Возраст от 25 до 35 лет, собственность от 2 до 10 и наличие 2 продуктов.
   # 'age >= 25 & age <= 35 & balance >= 0 & balance <= 3000000 & equity > 2 & products > 2', # Возраст от 25 до 35 лет, собственность от 2 до 10, баланс от 0 до 0,30 * 1е7 и наличие 2 продуктов.
   # 'gender == "М" & score > 820', # Женщины с низкими баллами и мужчины с высокими баллами.
   # 'age >= 25 & age <= 35 & score > 820 & score < 940', # Клиенты в возрасте от 25 до 35 с высокими баллами.
    #'balance >= 0 & balance <= 3000000 & score > 820 & score < 940', # Клиенты с низкими баллами и высоким балансом.
    'products > 2 & score > 820 & score < 940', # Клиенты с 2 продуктами и низкими баллами.
    #'equity > 2 & score > 820 & score < 940', # Клиенты с собственностью от 2 до 10 и высокими баллами.
    #'est_salary >= 10000 & est_salary <= 30000 & score > 820 & score < 940', # Клиенты с зарплатой от 0,1 до 0,3 * 1е5 и высокими баллами.
    #'score >= 820 & score <= 940 & age >= 25 & age <= 35 & products > 2', # Высокие баллы "score" (820-940), возраст от 25 до 35 лет и наличие 2 продуктов.
  ##  'score >= 820 & score <= 940 & equity > 2 & credit_card == 0', # Высокие баллы "score", собственность от 2 до 10 и отсутствие кредитной карты.
   # 'score >= 820 & score <= 940 & balance >= 0 & balance <= 3000000 & gender == "М"', # Высокие баллы "score", баланс от 0 до 0,30 * 1е7 и мужчины.
    #'score >= 820 & score <= 940 & age >= 25 & age <= 35 & equity > 2 & products > 2', # Высокие баллы "score", возраст от 25 до 35 лет, собственность от 2 до 10 и наличие 2 продуктов.
    #'score >= 820 & score <= 940 & age >= 25 & age <= 35 & balance >= 0 & balance <= 3000000 & products > 2', # Высокие баллы "score", возраст от 25 до 35 лет, баланс от 0 до 0,30 * 1е7 и наличие 2 продуктов.
   # 'score >= 820 & score <= 940 & age >= 25 & age <= 35 & equity > 2 & balance >= 0 & balance <= 3000000 & products > 2', # Высокие баллы "score", возраст от 25 до 35 лет, собственность от 2 до 10, баланс от 0 до 0,30 * 1е7 и наличие 2 продуктов.
    #'gender == "М" & age >= 25 & age <= 35 & score > 820 & score <= 940', # Мужчины, возраст от 25 до 35 лет и высокие баллы "score".
    #'gender == "М" & balance >= 0 & balance <= 3000000 & score > 820 & score <= 940', # Мужчины, баланс от 0 до 0,30 * 1е7 и высокие баллы "score".
    #'gender == "М" & equity > 2 & score > 820 & score <= 940', # Мужчины, собственность от 2 до 10 и высокие баллы "score".
    #'gender == "М" & products > 2 & score > 820 & score <= 940', # Мужчины, наличие 2 продуктов и высокие баллы "score".
    'gender == "М" & age >= 25 & age <= 35 & equity > 2 & score > 820 & score <= 940', # Мужчины, возраст от 25 до 35 лет, собственность от 2 до 10 и высокие баллы "score".
    #'gender == "М" & est_salary >= 10000 & est_salary <= 30000 & score > 820 & score <= 940', # Мужчины, зарплата от 0,1 до 0,3 * 1е5 и высокие баллы "score".
   ## 'age >= 25 & age <= 35 & equity > 2 & balance >= 0 & balance <= 3000000 & score > 820 & score <= 940', # Возраст от 25 до 35 лет, собственность от 2 до 10, баланс от 0 до 0,30 * 1е7 и высокие баллы "score".
    #'age >= 25 & age <= 35 & equity > 2 & products > 2 & score > 820 & score <= 940', # Возраст от 25 до 35 лет, собственность от 2 до 10, наличие 2 продуктов и высокие баллы "score".
    #'age >= 25 & age <= 35 & balance >= 0 & balance <= 3000000 & products > 2 & score > 820 & score <= 940', # Возраст от 25 до 35 лет, баланс от 0 до 0,30 * 1е7, наличие 2 продуктов и высокие баллы "score".
   # 'age >= 25 & age <= 35 & equity > 2 & balance >= 0 & balance <= 3000000 & products > 2 & score > 820 & score <= 940', # Возраст от 25 до 35 лет, собственность от 2 до 10, баланс от 0 до 0,30 * 1е7, наличие 2 продуктов и высокие баллы "score".
)



df_results = pd.concat([
    pd.DataFrame(df.query(q).agg({"churn":['mean','count']}).values,
                 columns=[q],
                 index=['Отток','Размер']).T 
    for q in qrys])

display(df_results.style.format("{:.1%}",subset=["Отток"])\
                   .format("{:_.0f}",subset=["Размер"]))
    
all_catched = pd.concat([df.query(q) for q in qrys])
all_churn = df.churn.sum()
catched = all_catched.drop_duplicates().churn.sum()
share_catched = catched / all_churn

ok = True
if len(qrys) != 3:
    ok = False
    print('\033[93m\033[1mРезультаты некорректны, нужно 3 лучших сегмента\033[0m')
    
if df_results['Отток'].min() < df.churn.mean() * 1.5:
    ok = False
    print('\033[93m\033[1mНужно изменить сегменты: присутствуют недостаточно отточные\033[0m')
elif df_results['Отток'].min() < df.churn.mean() * 2:
    print('Часть сегментов не высокоотточна')
elif df_results['Отток'].max() > df.churn.mean() * 3:
    print('Нашли очень отточный сегмент')

if df_results['Размер'].min() < 300:
    ok = False
    print('\033[93m\033[1mНужно изменить сегменты: присутствуют слишком мелкие сегменты\033[0m')
    
if all_catched.shape[0] > 5000:
    ok = False
    print("\033[93m\033[1mОтдел маркетинга не сможет обработать такое количество клиентов\033[0m")
elif all_catched.shape[0] > 3000:
    print("Отделу маркетинга будет сложно обработать такое количество клиентов, его эффективность снизится")
elif all_catched.shape[0] < 1000:
    print("Сегменты можно увеличить")

text_churn = f"{catched}/{all_churn} = {share_catched:.1%}"
if share_catched < 1/3:
    print(f"\033[93m\033[1mВ сегменты попало недостаточное число отточных: {text_churn}\033[0m")
elif ok:
    if 1/2 < share_catched < 2/3:
        print(f"Хороший результат, в сегменты попало: {text_churn}")
    elif share_catched >= 2/3:
        print(f"Прекрасный результат, в сегменты попало: {text_churn}")
    else:
        print(f"В сегменты попало: {text_churn}")
else:
    print(f"В сегменты попало: {text_churn}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_157d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_157d1_level0_col0" class="col_heading level0 col0" >Отток</th>
#       <th id="T_157d1_level0_col1" class="col_heading level0 col1" >Размер</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_157d1_level0_row0" class="row_heading level0 row0" >products > 2 & gender == "М"</th>
#       <td id="T_157d1_row0_col0" class="data row0 col0" >49.7%</td>
#       <td id="T_157d1_row0_col1" class="data row0 col1" >724</td>
#     </tr>
#     <tr>
#       <th id="T_157d1_level0_row1" class="row_heading level0 row1" >products > 2 & score > 820 & score < 940</th>
#       <td id="T_157d1_row1_col0" class="data row1 col0" >46.2%</td>
#       <td id="T_157d1_row1_col1" class="data row1 col1" >890</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;🔴<br>
# <span class="alert-danger">У нас задача выделить <b>отточные сегменты</b>.</span> Все сегменты выше имеют отток ниже среднего, т.е. они, наоборот, неотточны.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 3</b>&nbsp;🔴<br>
# <s>Нам не подойдут сегменты как с 60 и меньше клиентами так и с 6 тысячами. Ориентируйся на размер около 800, допустимо от 500 до 1500, в крайнем случае от 300 до 2000.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 4</b>&nbsp;🔧<br>
# Опять неотточные сегменты в результатах. Женщина - это не признак отточности. Ограничивать баллы собственности сверху не нужно. У тебя выше указано с 2 до 10 - т.е. 3+
#
# Пожалуйста, хоть раз используй каждый выделенный тобой признак отточности, кинешь мне скриншот потом в Пачку, обсудим как приоритизировать (выбрать три лучших)
#
# Попробуй механически объединить сначала все признаки попарно, потом добавить к недостаточно отточным ещё какие-то признаки, которые будут напрашиваться.
# </div>

# %% [markdown]
# ## Рекомендации

# %% [markdown]
# 1. Группа 1 (products > 2 & gender == "М"):Рекомендация: Обратите внимание на эту группу, так как процент оттока выше среднего. Исследуйте, почему клиенты с более чем двумя продуктами и мужского пола покидают компанию. Может потребоваться провести анализ причин оттока и предложить улучшения или бонусные программы для удержания этой группы.
#
#
# 2. Группа 2 (products > 2 & score > 820 & score < 940):Рекомендация: Изучите эту группу более подробно, чтобы выяснить, почему клиенты с более чем двумя продуктами и кредитным рейтингом от 820 до 940 уходят. Возможно, есть какие-то факторы или проблемы, которые необходимо решить, чтобы удержать эту группу.
#
# 3. Группа 3 (gender == "М" & age >= 25 & age <= 35 & equity > 2 & score > 820 & score <= 940):Рекомендация: Эта группа также имеет высокий процент оттока, и стоит провести дополнительное исследование, чтобы понять, что именно приводит к уходу мужчин в возрасте от 25 до 35 лет с кредитным рейтингом от 820 до 940 и с более чем двумя продуктами. Возможно, нужны персонализированные меры удержания для этой категории клиентов.

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 5&nbsp;<big>✔️</big></b> сегменты выделены ок, включи их в презентацию</div><div class="alert alert-danger"><b>Комментарий ревьюера 5</b>&nbsp;🔧<br>
# А вот таргетированных рекомендаций нет, их нужно придумать и тоже включить в презентацию.
# </div>
